# %%
#importing libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df_org = pd.read_csv("creditcard.csv")
df = df_org.copy()
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.165980e-15  3.416908e-16 -1.373150e-15  2.086869e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.490107e-15 -5.556467e-16  1.177556e-16 -2.406455e-15
# ...

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
def draw_missing_data_table(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
draw_missing_data_table(df)
# Out:
#         Total  Percent
# Class       0      0.0
# V14         0      0.0
# V1          0      0.0
# V2          0      0.0
# V3          0      0.0
# V4          0      0.0
# V5          0      0.0
# V6          0      0.0
# V7          0      0.0
# V8          0      0.0
# V9          0      0.0
# V10         0      0.0
# V11         0      0.0
# V12         0      0.0
# V13         0      0.0
# V15         0      0.0
# Amount      0      0.0
# V16         0      0.0
# V17         0      0.0
# V18         0      0.0
# V19         0      0.0
# V20         0      0.0
# V21         0      0.0
# V22         0      0.0
# V23         0      0.0
# V24         0      0.0
# V25         0      0.0
# V26         0      0.0
# V27         0      0.0
# V28         0      0.0
# Time        0      0.0

# %%
plt.figure(figsize=(15,5))
plt.hist(df[df.Class == 1]['Time'], bins = 50)
plt.title('Class 1')
# Out:
# Text(0.5, 1.0, 'Class 1')

# %%
plt.figure(figsize=(15,5))
plt.hist(df[df['Class'] == 0]['Time'], bins = 50)
plt.title('Class 0')
# Out:
# Text(0.5, 1.0, 'Class 0')

# %%
plt.figure(figsize=(15,5))

plt.hist(df[df['Class'] == 1]['Amount'], bins = 30)
plt.title('Class 1')
# Out:
# Text(0.5, 1.0, 'Class 1')

# %%
plt.figure(figsize=(15,5))
plt.hist(df[df['Class'] == 0]['Amount'], bins = 30)
plt.title('Class 0')
# Out:
# Text(0.5, 1.0, 'Class 0')

# %%
df.groupby('Class')['Amount'].mean()
# Out:
# Class
# 0     88.291022
# 1    122.211321
# Name: Amount, dtype: float64

# %%
df.groupby('Class')['Time'].mean()
# Out:
# Class
# 0    94838.202258
# 1    80746.806911
# Name: Time, dtype: float64

# %%
sns.barplot(df['Class'],df['Amount']);

# %%
df.groupby(['Class'])['Amount'].count()
# Out:
# Class
# 0    284315
# 1       492
# Name: Amount, dtype: int64

# %%
plt.figure(figsize=(15,5))

plt.scatter(df[df['Class'] == 1]['Time'], df[df['Class'] == 1]['Amount'])
plt.title('Class 1')
# Out:
# Text(0.5, 1.0, 'Class 1')

# %%
plt.figure(figsize=(15,5))

plt.scatter(df[df['Class'] == 0]['Time'], df[df['Class'] == 0]['Amount'])
plt.title('Fraud')
# Out:
# Text(0.5, 1.0, 'Fraud')

# %%
cols = list(df.columns)[1:-2]

# %%
plt.figure(figsize=(15,30))
for i in range(1, 28):
    plt.subplot(14, 2, i)
    col = cols[i]
    sns.distplot(df[col][df.Class == 1], bins=50)
    sns.distplot(df[col][df.Class == 0], bins=50)

# %%
df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021130F5B5C8>,
# ...
#       dtype=object)

# %%
df['V28'].hist(bins=50, figsize=(10,5),range=[-3, 3],align='mid')

# %%
df['V5'].hist(bins=50, figsize=(10,5),range=[-6.5, 12.5], align='mid')

# %%
from pandas.plotting import scatter_matrix

attributes = list(df.columns)[1:]
scatter_matrix(df[attributes], figsize=(28, 28))

# %%
df.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
correlation_matrix = df.corr()
fig = plt.figure(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=0.8,square = True)
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(18,4))

sns.distplot(df['Amount'].values,ax=ax[0],color='r')
ax[0].set_title('Amount value analysis', fontsize=14)
ax[0].set_xlim(-100,2000)
# ax[0].set_xticks(range(-3,3))


sns.distplot(df['Time'].values,ax=ax[1],color='g')
ax[1].set_title('Time value analysis', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Time value analysis')

# %%
print('Class 0', round(df['Class'].value_counts()[0]/len(df) * 100,2), '% of the dataset-----', round(df['Class'].value_counts()[0]))
print('Class 1', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset-----', round(df['Class'].value_counts()[1]))
# Out:
# Class 0 99.83 % of the dataset----- 284315
# Class 1 0.17 % of the dataset----- 492

# %%
class_0 = df.loc[df['Class']==1][:500]
class_1 = df.loc[df['Class']==0][:492]

# %%
new_df = pd.concat([class_0,class_1])

# %%
new_df=new_df.sample(frac=1,random_state=42)

# %%
print('Class 0', round(new_df['Class'].value_counts()[0]/len(new_df) * 100,2), '% of the dataset-----', round(new_df['Class'].value_counts()[0]))
print('Class 1', round(new_df['Class'].value_counts()[1]/len(new_df) * 100,2), '% of the dataset-----', round(new_df['Class'].value_counts()[1]))
# Out:
# Class 0 50.0 % of the dataset----- 492
# Class 1 50.0 % of the dataset----- 492

# %%
sns.countplot('Class',data=new_df)
plt.title('New Distributin Dataset')
plt.show()

# %%
fig,ax=plt.subplots(1,2,figsize=(18,4))

sns.distplot(new_df['Amount'].values,ax=ax[0],color='r')
ax[0].set_title('Amount value analysis', fontsize=14)
ax[0].set_xlim(-100,2000)
# ax[0].set_xticks(range(-3,3))


sns.distplot(new_df['Time'].values,ax=ax[1],color='g')
ax[1].set_title('Time value analysis', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Time value analysis')

# %%
f,(ax1,ax2)=plt.subplots(2,1,figsize=(24,20))


corr=df.corr()
sns.heatmap(corr,cmap='coolwarm_r', annot_kws={'size':20},ax=ax1)


new_corr_df=new_df.corr()
sns.heatmap(new_corr_df,cmap='coolwarm_r', annot_kws={'size':20},ax=ax2)

plt.show()

# %%
bins = numpy.linspace(-10, 10, 30)
plt.figure(figsize=(15,30))
for i in range(1, 28):
    plt.subplot(14, 2, i)
    col = cols[i]
    pyplot.hist(new_df[col][new_df.Class == 1], alpha=0.5, label='x')
    pyplot.hist(new_df[col][new_df.Class == 0], alpha=0.5, label='y')
    
    

pyplot.legend(loc='upper right')
pyplot.show()

# %%
new_df.hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021010A9E948>,
# ...
#       dtype=object)

# %%
# # Produce a scatter matrix for each pair of features in the data
# from pandas.plotting import scatter_matrix
# scatter_matrix(new_df, alpha = 0.2, figsize = (20,20), diagonal = 'kde')

# %%
X = new_df[list(new_df.columns)[0:-1]]
y = new_df['Class']

# %%
len(y)
# Out:
# 984

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() #linear scaling
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_train
# Out:
# array([[-0.78301953,  0.66575187, -0.49008981, ..., -0.07518534,
#          0.01951131, -0.11015829],
#        [ 1.66422414,  0.47697918, -0.04410624, ...,  0.33008593,
#          0.18717244, -0.0617418 ],
#        [-0.78156134,  0.43861813, -0.71482374, ...,  0.14741006,
#          0.48387046, -0.34403861],
#        ...,
#        [-0.77902371,  0.39539709, -0.27275433, ...,  0.14284223,
#          0.13259681, -0.36613659],
#        [-0.78243247, -0.39341616, -1.45763562, ...,  1.57379331,
#         -3.94370558,  3.34966971],
#        [-0.7778117 ,  0.64973042, -0.50636793, ..., -0.09103647,
#         -0.02722171,  0.03767923]])

# %% [markdown]
# # Logistic Regression

# %%
# Fitting classifier to the Training set
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[132,   0],
#        [  1, 113]], dtype=int64)

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9959349593495935

# %%
classifier.score(X_train, y_train)
# Out:
# 0.9959349593495935

# %%
from sklearn.metrics import plot_confusion_matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names= [0,1]

disp = plot_confusion_matrix(classifier, X_test, y_test,
                             display_labels=class_names,
                             cmap=plt.cm.Blues,
                             normalize=normalize)
disp.ax_.set_title(title)

print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.00877193 0.99122807]]

# %%
data_rank1 = new_df[new_df["Class"] == 1]
def plot_points(data):
    X = np.array(data[["Amount","Time"]])
    y = np.array(data["Class"])
    admitted = X[np.argwhere(y==1)]
    rejected = X[np.argwhere(y==0)]
    plt.scatter([s[0][0] for s in rejected], [s[0][1] for s in rejected], s = 25, color = 'red', edgecolor = 'k')
    plt.scatter([s[0][0] for s in admitted], [s[0][1] for s in admitted], s = 25, color = 'cyan', edgecolor = 'k')
    plt.xlabel('Amount')
    plt.ylabel('Time')
    
# Plotting the points
plot_points(new_df)
plt.show()

# %% [markdown]
# # SVM linear

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = "linear", random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_predt = classifier.predict(X_train)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, y_predt)
cm
# Out:
# array([[360,   0],
#        [  1, 377]], dtype=int64)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[132,   0],
#        [  1, 113]], dtype=int64)

# %%
classifier.score(X_train, y_train)
# Out:
# 0.9986449864498645

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9959349593495935

# %%
from sklearn.metrics import plot_confusion_matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names= [0,1]

disp = plot_confusion_matrix(classifier, X_test, y_test,
                             display_labels=class_names,
                             cmap=plt.cm.Blues,
                             normalize=normalize)
disp.ax_.set_title(title)

print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.00877193 0.99122807]]

# %% [markdown]
# # SVM rbf

# %%
# Fitting classifier to the Training set
from sklearn.svm import SVC
classifier = SVC(kernel = "rbf", random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
y_predt = classifier.predict(X_train)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, y_predt)
cm
# Out:
# array([[360,   0],
#        [  4, 374]], dtype=int64)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[131,   1],
#        [  1, 113]], dtype=int64)

# %%
classifier.score(X_train, y_train)
# Out:
# 0.994579945799458

# %%
classifier.score(X_test, y_test)
# Out:
# 0.991869918699187

# %%
from sklearn.metrics import plot_confusion_matrix
titles_options = [("Confusion matrix, without normalization", None),
                  ("Normalized confusion matrix", 'true')]
class_names= [0,1]

disp = plot_confusion_matrix(classifier, X_test, y_test,
                             display_labels=class_names,
                             cmap=plt.cm.Blues,
                             normalize=normalize)
disp.ax_.set_title(title)

print(title)
print(disp.confusion_matrix)

plt.show()
# Out:
# Normalized confusion matrix
# [[0.99242424 0.00757576]
#  [0.00877193 0.99122807]]
